# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Performance
#
# ## How programmers affects performance?

# %%
compare([do_render_code("./programmer/madd_A.c", lang="c++", show="main"),
do_render_code("./programmer/madd_B.c", lang="c++", show="main")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// ./programmer/madd_A.c:7-50 (44 lines)</span>
# <span class="kt">int</span><span class="w"> </span><span class="nf">main</span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="n">argc</span><span class="p">,</span><span class="w"> </span><span class="kt">char</span><span class="w"> </span><span class="o">**</span><span class="n">argv</span><span class="p">)</span>
# <span class="p">{</span>
# <span class="w">  </span><span class="kt">int</span><span class="w"> </span><span class="o">**</span><span class="n">a</span><span class="p">,</span><span class="w"> </span><span class="o">**</span><span class="n">b</span><span class="p">,</span><span class="w"> </span><span class="o">**</span><span class="n">c</span><span class="p">,</span><span class="w"> </span><span class="n">i</span><span class="p">,</span><span class="w"> </span><span class="n">j</span><span class="p">,</span><span class="w"> </span><span class="n">k</span><span class="p">;</span>
# <span class="w">  </span><span class="cm">/* initialize a, b */</span>
# <span class="w">  </span><span class="k">if</span><span class="p">(</span><span class="n">argc</span><span class="w"> </span><span class="o">&gt;=</span><span class="w"> </span><span class="mi">2</span><span class="p">)</span>
# <span class="w">    </span><span class="n">ARRAY_SIZE</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="n">atoi</span><span class="p">(</span><span class="n">argv</span><span class="p">[</span><span class="mi">1</span><span class="p">]);</span>
# <span class="w">  </span><span class="n">a</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="o">**</span><span class="p">)</span><span class="n">malloc</span><span class="p">(</span><span class="n">ARRAY_SIZE</span><span class="o">*</span><span class="k">sizeof</span><span class="p">(</span><span class="kt">int</span><span class="w"> </span><span class="o">*</span><span class="p">));</span>
# <span class="w">  </span><span class="k">for</span><span class="p">(</span><span class="n">i</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">&lt;</span><span class="w"> </span><span class="n">ARRAY_SIZE</span><span class="p">;</

# %%
! cd programmer; make clean; make
! echo "running version A"; perf stat ./programmer/madd_A
! echo "running version B"; perf stat ./programmer/madd_B
# Out:
# rm -f madd_A madd_B madd_change_freq madd_A_O1 madd_B_O1 madd_A_O2 madd_B_O2 madd_A_O3 madd_B_O3 madd_A_O4 madd_B_O4 *~
# #hotspot hotspot_omp
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_A.c -o madd_A
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_B.c -o madd_B
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O1 perfstats.o madd_A.c -o madd_A_O1
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O1 perfstats.o madd_B.c -o madd_B_O1
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O2 perfstats.o madd_A.c -o madd_A_O2
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O2 perfstats.o madd_B.c -o madd_B_O2
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3 perfstats.o madd_A.c -o madd_A_O3
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3 perfstats.o madd_B.c -o madd_B_O3
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O4 perfstats.o madd_A.c -o madd_A_O4
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O4 perfstats.o madd_B.c -o madd_B_O4
# cc -O3 -DHAVE_LINUX_PERF_EVENT_H -g -DA madd_change_freq.c perfstats.o -o madd_change_freq
# madd_change_freq.c: In function ‘main’:
# madd_change_freq.c:18:3: warning: implicit declaration of function ‘change_cpufrequnecy’ [-Wimplicit-function-declaration]
#    18 |   change_cpufrequnecy(freq);
#       |   ^~~~~~~~~~~~~~~~~~~
# madd_change_freq.c:49:3: warning: implicit declaration of function ‘restore_cpufrequnecy’ [-Wimplicit-function-declaration]
#    49 |   restore_cpufrequnecy();
#       |   ^~~~~~~~~~~~~~~~~~~~
# running version A
# 161
#
#  Performance counter stats for './programmer/madd_A':
#
#           1,784.11 msec task-clock                       #    0.998 CPUs utilized
#                  9      context-switches                 #    5.045 /sec
#                  2      cpu-migrations                   #    1.121 /sec
#            196,815      page-faults                      #  110.315 K/sec
#      1,369,370,313      cpu_atom/cycles/                 #    0.768 GHz                         (0.10%)
#      9,147,342,793      cpu_core/cycles/                 #    5.127 GHz                         (98.85%)
#      1,833,155,668      cpu_atom/instructions/           #    1.34  insn per cycle              (0.16%)
#     16,024,172,398      cpu_core/instructions/           #   11.70  insn per cycle              (98.89%)
#        335,709,735      cpu_atom/branches/               #  188.166 M/sec                       (0.16%)
#      2,507,666,634      cpu_core/branches/               #    1.406 G/sec                       (98.44%)
#          3,695,270      cpu_atom/branch-misses/          #    1.10% of all branches             (0.21%)
#          4,706,118      cpu_core/branch-misses/          #    1.40% of all branches             (98.44%)
#              TopdownL1 (cpu_core)                 #     64.0 %  tma_backend_bound
#                                                   #      0.8 %  tma_bad_speculation
#                                                   #      3.1 %  tma_frontend_bound
#                                                   #     32.0 %  tma_retiring             (98.89%)
#              TopdownL1 (cpu_atom)                 #      0.8 %  tma_bad_speculation
#                                                   #     33.5 %  tma_retiring             (0.22%)
#                                                   #     52.1 %  tma_backend_bound
#                                                   #     52.1 %  tma_backend_bound_aux
#                                                   #     13.5 %  tma_frontend_bound       (0.22%)
#
#        1.787579666 seconds time elapsed
#
#        1.613460000 seconds user
#        0.171942000 seconds sys
#
#
# running version B
# 161
#
#  Performance counter stats for './programmer/madd_B':
#
#           2,251.59 msec task-clock                       #    0.999 CPUs utilized
#                 14      context-switches                 #    6.218 /sec
#                  6      cpu-migrations                   #    2.665 /sec
#            196,817      page-faults                      #   87.412 K/sec
#      8,391,526,014      cpu_atom/cycles/                 #    3.727 GHz                         (0.11%)
#     11,611,912,618      cpu_core/cycles/                 #    5.157 GHz                         (95.54%)
#     18,673,706,038      cpu_atom/instructions/           #    2.23  insn per cycle              (0.15%)
#     16,593,725,277      cpu_core/instructions/           #    1.98  insn per cycle              (95.54%)
#      1,840,185,776      cpu_atom/branches/               #  817.282 M/sec                       (0.15%)
#      2,645,379,139      cpu_core/branches/               #    1.175 G/sec                       (93.41%)
#          7,075,019      cpu_atom/branch-misses/          #    0.38% of all branches             (0.15%)
#          4,925,353      cpu_core/branch-misses/          #    0.27% of all branches             (93.41%)
#              TopdownL1 (cpu_core)                 #     64.0 %  tma_backend_bound
#                                                   #      0.8 %  tma_bad_speculation
#                                                   #      3.1 %  tma_frontend_bound
#                                                   #     32.0 %  tma_retiring             (95.55%)
#              TopdownL1 (cpu_atom)                 #      3.2 %  tma_bad_speculation
#                                                   #     50.8 %  tma_retiring             (0.19%)
#                                                   #     36.9 %  tma_backend_bound
#                                                   #     36.9 %  tma_backend_bound_aux
#                                                   #      9.0 %  tma_frontend_bound       (0.19%)
#
#        2.254481654 seconds time elapsed
#
#        2.092016000 seconds user
#        0.160001000 seconds sys

# %%
! lscpu

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Question:
#
# What does the programmer affect?
#
# </div>

# %%
compare([do_render_code("../intro/arraySort.cpp",lang="c++", show="main"),do_render_code("../intro/calculate_sum.c",lang="c++", show="calculate_sum")])

# %%
! cd ../intro/; make clean; make; echo "not sorting"; perf stat ./arraySort 262144 1000 0; echo "sorting"; perf stat  ./arraySort 262144 1000 1

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Question:
#
# What does the programmer affect?
#
# </div>

# %%
render_code("./programmer/perfstats.c", lang="c++", show="change_cpufrequnecy")

# %%
# !srun -N1 cpupower frequency-info -n

# %%
! srun -N1 cat /proc/cpuinfo|grep MHz

# %%
! cs203 job run "perf stat ./programmer/madd_change_freq 8192 1400"
! cs203 job run "perf stat ./programmer/madd_change_freq 8192 3600"

# %% [markdown]
# ## How programming languages affects performance?
#
# ### Python

# %%
render_code("./programming_languages/hello.py")
# Out:
# // ./programming_languages/hello.py:1-1 (1 lines)
# print("Hello, World!")

# %%
# !perf stat python ./programming_languages/hello.py
# Out:
# Hello, World!
#
#  Performance counter stats for 'python ./programming_languages/hello.py':
#
#              10.62 msec task-clock                       #    0.876 CPUs utilized
#                  3      context-switches                 #  282.439 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                901      page-faults                      #   84.826 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#         30,653,854      cpu_core/cycles/                 #    2.886 GHz
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#         49,103,892      cpu_core/instructions/
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#         10,409,057      cpu_core/branches/               #  979.976 M/sec
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#            343,413      cpu_core/branch-misses/
#              TopdownL1 (cpu_core)                 #     16.0 %  tma_backend_bound
#                                                   #     22.9 %  tma_bad_speculation
#                                                   #     35.5 %  tma_frontend_bound
#                                                   #     25.7 %  tma_retiring
#
#        0.012127384 seconds time elapsed
#
#        0.007941000 seconds user
#        0.003529000 seconds sys

# %% [markdown]
# ### Perl

# %%
render_code("./programming_languages/hello.pl")
# Out:
# // ./programming_languages/hello.pl:1-5 (5 lines)
# #!/usr/bin/perl
# use strict;
# use warnings;
#
# print "Hello, World!\n";

# %%
! perf stat ./programming_languages/hello.pl
# Out:
# Hello, World!
#
#  Performance counter stats for './programming_languages/hello.pl':
#
#               8.12 msec task-clock                       #    0.828 CPUs utilized
#                  3      context-switches                 #  369.563 /sec
#                  1      cpu-migrations                   #  123.188 /sec
#                310      page-faults                      #   38.188 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#          8,829,323      cpu_core/cycles/                 #    1.088 GHz
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#         14,531,499      cpu_core/instructions/
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#          2,976,388      cpu_core/branches/               #  366.655 M/sec
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#             73,251      cpu_core/branch-misses/
#              TopdownL1 (cpu_core)                 #     14.8 %  tma_backend_bound
#                                                   #     13.8 %  tma_bad_speculation
#                                                   #     44.9 %  tma_frontend_bound
#                                                   #     26.5 %  tma_retiring
#
#        0.009807866 seconds time elapsed
#
#        0.006017000 seconds user
#        0.003008000 seconds sys

# %% [markdown]
# ### Java

# %%
render_code("./programming_languages/HelloWorld.java")
# Out:
# // ./programming_languages/HelloWorld.java:1-8 (8 lines)
# public class HelloWorld {
#
#     public static void main(String[] args) {
#         // Prints "Hello, World" to the terminal window.
#         System.out.println("Hello, World");
#     }
#
# }

# %%
! cd ./programming_languages/; javac HelloWorld.java
! cd ./programming_languages/; perf stat java HelloWorld
# Out:
# /bin/bash: line 1: javac: command not found
# Hello, World
#
#  Performance counter stats for 'java HelloWorld':
#
#              38.02 msec task-clock                       #    0.859 CPUs utilized
#                 88      context-switches                 #    2.315 K/sec
#                 17      cpu-migrations                   #  447.128 /sec
#              6,168      page-faults                      #  162.228 K/sec
#          6,581,095      cpu_atom/cycles/                 #    0.173 GHz                         (5.23%)
#         89,356,583      cpu_core/cycles/                 #    2.350 GHz                         (92.78%)
#          9,733,568      cpu_atom/instructions/           #    1.48  insn per cycle              (27.44%)
#        117,952,166      cpu_core/instructions/           #   17.92  insn per cycle              (92.78%)
#          3,150,650      cpu_atom/branches/               #   82.867 M/sec                       (39.90%)
#         21,116,471      cpu_core/branches/               #  555.397 M/sec                       (92.78%)
#            109,705      cpu_atom/branch-misses/          #    3.48% of all branches             (39.96%)
#            417,527      cpu_core/branch-misses/          #   13.25% of all branches             (92.78%)
#              TopdownL1 (cpu_core)                 #     36.6 %  tma_backend_bound
#                                                   #     11.1 %  tma_bad_speculation
#                                                   #     28.9 %  tma_frontend_bound
#                                                   #     23.4 %  tma_retiring             (92.78%)
#              TopdownL1 (cpu_atom)                 #     13.3 %  tma_bad_speculation
#                                                   #     21.2 %  tma_retiring             (39.96%)
#                                                   #     28.5 %  tma_backend_bound
#                                                   #     28.5 %  tma_backend_bound_aux
#                                                   #     36.9 %  tma_frontend_bound       (39.96%)
#
#        0.044237696 seconds time elapsed
#
#        0.014409000 seconds user
#        0.024702000 seconds sys

# %% [markdown]
# ### Go

# %%
render_code("./programming_languages/hello-world.go")
# Out:
# // ./programming_languages/hello-world.go:1-5 (5 lines)
# package main
# import "fmt"
# func main() {
#     fmt.Println("hello world")
# }

# %%
! perf stat /usr/local/go/bin/go run ./programming_languages/hello-world.go
# Out:
# Workload failed: No such file or directory

# %%
# !/usr/local/go/bin/go build ./programming_languages/hello-world.go
! perf stat ./hello-world
# Out:
# /bin/bash: line 1: /usr/local/go/bin/go: No such file or directory
# hello world
#
#  Performance counter stats for './hello-world':
#
#               8.07 msec task-clock                       #    0.119 CPUs utilized
#                 58      context-switches                 #    7.185 K/sec
#                  2      cpu-migrations                   #  247.749 /sec
#                278      page-faults                      #   34.437 K/sec
#          5,169,876      cpu_atom/cycles/                 #    0.640 GHz                         (79.72%)
#          6,345,465      cpu_core/cycles/                 #    0.786 GHz                         (17.57%)
#          5,011,346      cpu_atom/instructions/           #    0.97  insn per cycle              (83.54%)
#          6,068,462      cpu_core/instructions/           #    1.17  insn per cycle              (17.57%)
#            875,696      cpu_atom/branches/               #  108.476 M/sec                       (80.76%)
#          1,127,563      cpu_core/branches/               #  139.676 M/sec                       (17.57%)
#             23,817      cpu_atom/branch-misses/          #    2.72% of all branches             (60.38%)
#             29,501      cpu_core/branch-misses/          #    3.37% of all branches             (17.57%)
#              TopdownL1 (cpu_core)                 #     41.0 %  tma_backend_bound
#                                                   #      8.3 %  tma_bad_speculation
#                                                   #     34.2 %  tma_frontend_bound
#                                                   #     16.5 %  tma_retiring             (17.57%)
#              TopdownL1 (cpu_atom)                 #     10.7 %  tma_bad_speculation
#                                                   #     26.9 %  tma_retiring             (56.39%)
#                                                   #     29.5 %  tma_backend_bound
#                                                   #     29.5 %  tma_backend_bound_aux
#                                                   #     32.9 %  tma_frontend_bound       (72.18%)
#
#        0.068102847 seconds time elapsed
#
#        0.000000000 seconds user
#        0.009625000 seconds sys

# %% [markdown]
# ### C++

# %%
render_code("./programming_languages/hello.cpp")
# Out:
# // ./programming_languages/hello.cpp:1-8 (8 lines)
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     cout << "Hello, World!";
#     return 0;
# }

# %%
! g++ -O4 ./programming_languages/hello.cpp -o ./programming_languages/hello_cpp
! perf stat ./programming_languages/hello_cpp
# Out:
# Hello, World!
#  Performance counter stats for './programming_languages/hello_cpp':
#
#               2.07 msec task-clock                       #    0.571 CPUs utilized
#                  0      context-switches                 #    0.000 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                127      page-faults                      #   61.254 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#          2,339,501      cpu_core/cycles/                 #    1.128 GHz
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#          3,651,304      cpu_core/instructions/
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#            653,230      cpu_core/branches/               #  315.063 M/sec
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#             15,671      cpu_core/branch-misses/
#              TopdownL1 (cpu_core)                 #     23.8 %  tma_backend_bound
#                                                   #     15.8 %  tma_bad_speculation
#                                                   #     33.4 %  tma_frontend_bound
#                                                   #     27.0 %  tma_retiring
#
#        0.003631949 seconds time elapsed
#
#        0.001421000 seconds user
#        0.001421000 seconds sys

# %% [markdown]
# ### C

# %%
render_code("./programming_languages/hello.c")
# Out:
# // ./programming_languages/hello.c:1-7 (7 lines)
# #include <stdio.h>
#
# int main()
# {
#     printf("Hello, world!\n");
#     return 0;
# }

# %%
! gcc -O4 ./programming_languages/hello.c -o ./programming_languages/hello_c
! perf stat ./programming_languages/hello_c
# Out:
# Hello, world!
#
#  Performance counter stats for './programming_languages/hello_c':
#
#               0.82 msec task-clock                       #    0.358 CPUs utilized
#                  0      context-switches                 #    0.000 /sec
#                  0      cpu-migrations                   #    0.000 /sec
#                 57      page-faults                      #   69.344 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#            874,541      cpu_core/cycles/                 #    1.064 GHz
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#          1,004,024      cpu_core/instructions/
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#            182,366      cpu_core/branches/               #  221.860 M/sec
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#              6,203      cpu_core/branch-misses/
#              TopdownL1 (cpu_core)                 #     20.2 %  tma_backend_bound
#                                                   #     12.3 %  tma_bad_speculation
#                                                   #     45.7 %  tma_frontend_bound
#                                                   #     21.8 %  tma_retiring
#
#        0.002294006 seconds time elapsed
#
#        0.000000000 seconds user
#        0.001820000 seconds sys

# %% [markdown]
# ## Compiler

# %%
! make -C programmer clean; make -C programmer madd_A; rm madd.csv
! echo "program,IC,Cycles,CPI,Freq(MHz),CT,ET" > madd.csv
! echo "running version A (Unoptimized)"
! perf stat ./programmer/madd_A
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# rm -f madd_A madd_B madd_change_freq madd_A_O1 madd_B_O1 madd_A_O2 madd_B_O2 madd_A_O3 madd_B_O3 madd_A_O4 madd_B_O4 *~
# #hotspot hotspot_omp
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_A.c -o madd_A
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/performance/programmer'
# running version A (Unoptimized)
# 161
#
#  Performance counter stats for './programmer/madd_A':
#
#           1,794.20 msec task-clock                       #    0.998 CPUs utilized
#                 13      context-switches                 #    7.246 /sec
#                  5      cpu-migrations                   #    2.787 /sec
#            196,816      page-faults                      #  109.696 K/sec
#      <not counted>      cpu_atom/cycles/                                                        (0.00%)
#      9,206,539,763      cpu_core/cycles/                 #    5.131 GHz                         (99.08%)
#      <not counted>      cpu_atom/instructions/                                                  (0.00%)
#     16,006,743,880      cpu_core/instructions/                                                  (99.11%)
#      <not counted>      cpu_atom/branches/                                                      (0.00%)
#      2,504,382,605      cpu_core/branches/               #    1.396 G/sec                       (98.66%)
#      <not counted>      cpu_atom/branch-misses/                                                 (0.00%)
#          4,702,009      cpu_core/branch-misses/                                                 (98.66%)
#              TopdownL1 (cpu_core)                 #     64.2 %  tma_backend_bound
#                                                   #      1.2 %  tma_bad_speculation
#                                                   #      3.1 %  tma_frontend_bound
#                                                   #     31.5 %  tma_retiring             (99.11%)
#
#        1.797624537 seconds time elapsed
#
#        1.623007000 seconds user
#        0.172106000 seconds sys

# %%
! cd programmer; make clean; make madd_B
! echo "running version B (Unoptimized)"; time ./programmer/madd_B
# Out:
# rm -f madd_A madd_B madd_change_freq madd_A_O1 madd_B_O1 madd_A_O2 madd_B_O2 madd_A_O3 madd_B_O3 madd_A_O4 madd_B_O4 *~
# #hotspot hotspot_omp
# cc -O0 -DHAVE_LINUX_PERF_EVENT_H -g perfstats.o madd_B.c -o madd_B
# running version B (Unoptimized)
# 161
#
# real	0m2.200s
# user	0m2.023s
# sys	0m0.169s

# %%
! cd programmer;make madd_A_O1; make madd_A_O2; make madd_A_O3; make madd_A_O4
#! echo "running version A (Optimized)"
#! perf stat ./programmer/madd_A_O4
# !./programmer/madd_A_O1; ./programmer/madd_A_O2; ./programmer/madd_A_O3; ./programmer/madd_A_O4
# Out:
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O1 perfstats.o madd_A.c -o madd_A_O1
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O2 perfstats.o madd_A.c -o madd_A_O2
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3 perfstats.o madd_A.c -o madd_A_O3
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O4 perfstats.o madd_A.c -o madd_A_O4
# 161
# 161
# 161
# 161

# %%
#! cd programmer; make madd_B_O3
#! echo "running version B (Optimized)"; time ./programmer/madd_B_O3
! cd programmer;make madd_B_O1; make madd_B_O2; make madd_B_O3; make madd_B_O4
# !./programmer/madd_B_O1; ./programmer/madd_B_O2; ./programmer/madd_B_O3; ./programmer/madd_B_O4
# Out:
# make: 'madd_B_O1' is up to date.
# make: 'madd_B_O2' is up to date.
# make: 'madd_B_O3' is up to date.
# make: 'madd_B_O4' is up to date.
# 161
# 161
# 161
# 161

# %%
display_df_mono(render_csv("madd.csv"))
# Out:
# <style type="text/css">
# #T_ad4e0_row0_col0, #T_ad4e0_row0_col1, #T_ad4e0_row0_col2, #T_ad4e0_row0_col3, #T_ad4e0_row0_col4, #T_ad4e0_row0_col5, #T_ad4e0_row0_col6, #T_ad4e0_row1_col0, #T_ad4e0_row1_col1, #T_ad4e0_row1_col2, #T_ad4e0_row1_col3, #T_ad4e0_row1_col4, #T_ad4e0_row1_col5, #T_ad4e0_row1_col6, #T_ad4e0_row2_col0, #T_ad4e0_row2_col1, #T_ad4e0_row2_col2, #T_ad4e0_row2_col3, #T_ad4e0_row2_col4, #T_ad4e0_row2_col5, #T_ad4e0_row2_col6, #T_ad4e0_row3_col0, #T_ad4e0_row3_col1, #T_ad4e0_row3_col2, #T_ad4e0_row3_col3, #T_ad4e0_row3_col4, #T_ad4e0_row3_col5, #T_ad4e0_row3_col6, #T_ad4e0_row4_col0, #T_ad4e0_row4_col1, #T_ad4e0_row4_col2, #T_ad4e0_row4_col3, #T_ad4e0_row4_col4, #T_ad4e0_row4_col5, #T_ad4e0_row4_col6, #T_ad4e0_row5_col0, #T_ad4e0_row5_col1, #T_ad4e0_row5_col2, #T_ad4e0_row5_col3, #T_ad4e0_row5_col4, #T_ad4e0_row5_col5, #T_ad4e0_row5_col6, #T_ad4e0_row6_col0, #T_ad4e0_row6_col1, #T_ad4e0_row6_col2, #T_ad4e0_row6_col3, #T_ad4e0_row6_col4, #T_ad4e0_row6_col5, #T_ad4e0_row6_col6, #T_ad4e0_row7_col0, #T_ad4e0_row7_col1, #T_ad4e0_row7_col2, #T_ad4e0_row7_col3, #T_ad4e0_row7_col4, #T_ad4e0_row7_col5, #T_ad4e0_row7_col6, #T_ad4e0_row8_col0, #T_ad4e0_row8_col1, #T_ad4e0_row8_col2, #T_ad4e0_row8_col3, #T_ad4e0_row8_col4, #T_ad4e0_row8_col5, #T_ad4e0_row8_col6, #T_ad4e0_row9_col0, #T_ad4e0_row9_col1, #T_ad4e0_row9_col2, #T_ad4e0_row9_col3, #T_ad4e0_row9_col4, #T_ad4e0_row9_col5, #T_ad4e0_row9_col6, #T_ad4e0_row10_col0, #T_ad4e0_row10_col1, #T_ad4e0_row10_col2, #T_ad4e0_row10_col3, #T_ad4e0_row10_col4, #T_ad4e0_row10_col5, #T_ad4e0_row10_col6, #T_ad4e0_row11_col0, #T_ad4e0_row11_col1, #T_ad4e0_row11_col2, #T_ad4e0_row11_col3, #T_ad4e0_row11_col4, #T_ad4e0_row11_col5, #T_ad4e0_row11_col6, #T_ad4e0_row12_col0, #T_ad4e0_row12_col1, #T_ad4e0_row12_col2, #T_ad4e0_row12_col3, #T_ad4e0_row12_col4, #T_ad4e0_row12_col5, #T_ad4e0_row12_col6, #T_ad4e0_row13_col0, #T_ad4e0_row13_col1, #T_ad4e0_row13_col2, #T_ad4e0_row13_col3, #T_ad4e0_row13_col4, #T_ad4e0_row13_col5, #T_ad4e0_row13_col6 {
#   background-color: grey;
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_ad4e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad4e0_level0_col0" class="col_heading level0 col0" >program</th>
#       <th id="T_ad4e0_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_ad4e0_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_ad4e0_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_ad4e0_level0_col4" class="col_heading level0 col4" >Freq(MHz)</th>
#       <th id="T_ad4e0_level0_col5" class="col_heading level0 col5" >CT</th>
#       <th id="T_ad4e0_level0_col6" class="col_heading level0 col6" >ET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad4e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad4e0_row0_col0" class="data row0 col0" >./programmer/madd_A</td>
#       <td id="T_ad4e0_row0_col1" class="data row0 col1" >2131969743</td>
#       <td id="T_ad4e0_row0_col2" class="data row0 col2" >418123112</td>
#       <td id="T_ad4e0_row0_col3" class="data row0 col3" >0.196121</td>
#       <td id="T_ad4e0_row0_col4" class="data row0 col4" >4304.556669</td>
#       <td id="T_ad4e0_row0_col5" class="data row0 col5" >0.232312</td>
#       <td id="T_ad4e0_row0_col6" class="data row0 col6" >0.097135</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad4e0_row1_col0" class="data row1 col0" >./programmer/madd_B</td>
#       <td id="T_ad4e0_row1_col1" class="data row1 col1" >2556613269</td>
#       <td id="T_ad4e0_row1_col2" class="data row1 col2" >2985256919</td>
#       <td id="T_ad4e0_row1_col3" class="data row1 col3" >1.167661</td>
#       <td id="T_ad4e0_row1_col4" class="data row1 col4" >5169.240246</td>
#       <td id="T_ad4e0_row1_col5" class="data row1 col5" >0.193452</td>
#       <td id="T_ad4e0_row1_col6" class="data row1 col6" >0.577504</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad4e0_row2_col0" class="data row2 col0" >./programmer/madd_A_O1</td>
#       <td id="T_ad4e0_row2_col1" class="data row2 col1" >403113205</td>
#       <td id="T_ad4e0_row2_col2" class="data row2 col2" >180322198</td>
#       <td id="T_ad4e0_row2_col3" class="data row2 col3" >0.447324</td>
#       <td id="T_ad4e0_row2_col4" class="data row2 col4" >5181.076830</td>
#       <td id="T_ad4e0_row2_col5" class="data row2 col5" >0.193010</td>
#       <td id="T_ad4e0_row2_col6" class="data row2 col6" >0.034804</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad4e0_row3_col0" class="data row3 col0" >./programmer/madd_A_O2</td>
#       <td id="T_ad4e0_row3_col1" class="data row3 col1" >403107271</td>
#       <td id="T_ad4e0_row3_col2" class="data row3 col2" >180046948</td>
#       <td id="T_ad4e0_row3_col3" class="data row3 col3" >0.446648</td>
#       <td id="T_ad4e0_row3_col4" class="data row3 col4" >5179.567561</td>
#       <td id="T_ad4e0_row3_col5" class="data row3 col5" >0.193066</td>
#       <td id="T_ad4e0_row3_col6" class="data row3 col6" >0.034761</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad4e0_row4_col0" class="data row4 col0" >./programmer/madd_A_O3</td>
#       <td id="T_ad4e0_row4_col1" class="data row4 col1" >117941317</td>
#       <td id="T_ad4e0_row4_col2" class="data row4 col2" >162963577</td>
#       <td id="T_ad4e0_row4_col3" class="data row4 col3" >1.381734</td>
#       <td id="T_ad4e0_row4_col4" class="data row4 col4" >5185.629001</td>
#       <td id="T_ad4e0_row4_col5" class="data row4 col5" >0.192841</td>
#       <td id="T_ad4e0_row4_col6" class="data row4 col6" >0.031426</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad4e0_row5_col0" class="data row5 col0" >./programmer/madd_A_O4</td>
#       <td id="T_ad4e0_row5_col1" class="data row5 col1" >117884998</td>
#       <td id="T_ad4e0_row5_col2" class="data row5 col2" >162718368</td>
#       <td id="T_ad4e0_row5_col3" class="data row5 col3" >1.380314</td>
#       <td id="T_ad4e0_row5_col4" class="data row5 col4" >5186.077511</td>
#       <td id="T_ad4e0_row5_col5" class="data row5 col5" >0.192824</td>
#       <td id="T_ad4e0_row5_col6" class="data row5 col6" >0.031376</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad4e0_row6_col0" class="data row6 col0" >./programmer/madd_B_O1</td>
#       <td id="T_ad4e0_row6_col1" class="data row6 col1" >611286600</td>
#       <td id="T_ad4e0_row6_col2" class="data row6 col2" >3472692603</td>
#       <td id="T_ad4e0_row6_col3" class="data row6 col3" >5.680957</td>
#       <td id="T_ad4e0_row6_col4" class="data row6 col4" >5181.692522</td>
#       <td id="T_ad4e0_row6_col5" class="data row6 col5" >0.192987</td>
#       <td id="T_ad4e0_row6_col6" class="data row6 col6" >0.670185</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad4e0_row7_col0" class="data row7 col0" >./programmer/madd_B_O2</td>
#       <td id="T_ad4e0_row7_col1" class="data row7 col1" >611255184</td>
#       <td id="T_ad4e0_row7_col2" class="data row7 col2" >3477565005</td>
#       <td id="T_ad4e0_row7_col3" class="data row7 col3" >5.689220</td>
#       <td id="T_ad4e0_row7_col4" class="data row7 col4" >5176.773661</td>
#       <td id="T_ad4e0_row7_col5" class="data row7 col5" >0.193171</td>
#       <td id="T_ad4e0_row7_col6" class="data row7 col6" >0.671763</td>
#     </tr>
#     <tr>
#       <th id="T_ad4e0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad4e0_row8_col0" class="data row8 col0" >./programmer/madd_B_O3</td>
#       <td id="T_ad4e0_row8_col1" class="data row8 col1" >611428652</td>
#       <td id="T_ad4e0_row8_col2" class="data row8 col2" >3486850663</td>
#       <td id="T_ad4e0_row8_col3" class="data row8

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Question:
#
# What's the limitation of compiler?
#
# </div>
