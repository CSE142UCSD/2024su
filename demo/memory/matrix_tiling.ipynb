# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Case study: matrix multiplications
#
# GEMM that computes C = A $\times$ B is the core of many AI/ML applications. The most naive implementation of GEMM takes $O(n^3)$. Assume it takes 1 second to perform GEMM on 1,024$\times$1,024$\times$1,024 matrices. How much time do you expect it would take for 2,048$\times$2,048$\times$2,048 matrices?

# %%
render_code("matrix_mul/mm.c", show=["//START","//END"])
# Out:
# // matrix_mul/mm.c:71-92 (22 lines)
# //START
# void mm(double **a, double **b, double **c)
# {
#   int i,j,k;
#   for(i = 0; i < ARRAY_SIZE; i++)
#   {
#     for(j = 0; j < ARRAY_SIZE; j++)
#     {
#       for(k = 0; k < ARRAY_SIZE; k++)
#       {
#         c[i][j] += a[i][k]*b[k][j];
#         #ifdef DUMP
#           fprintf(stderr, "a[%d][%d], %p\n",i,k, &a[i][k]);
#           fprintf(stderr, "b[%d][%d], %p\n",k,j, &b[k][j]);
#           fprintf(stderr, "c[%d][%d], %p\n",i,j, &c[i][j]);
#         #endif
#       }
#     }
#   }
#   return;
# }
# //END

# %%
! cd matrix_mul; make clean; make mm
# Out:
# rm -f blockmm mm blockmm_transpose cachegrind.* mm_dump
# gcc -DHAVE_LINUX_PERF_EVENT_H -O3 mm.c perfstats.c -o mm

# %%
! cd matrix_mul; echo "IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > mm.csv
! ./matrix_mul/mm 512 >> ./matrix_mul/mm.csv ;./matrix_mul/mm 1024 >> ./matrix_mul/mm.csv ; ./matrix_mul/mm 2048 >> ./matrix_mul/mm.csv
#! cs203 job memory "./matrix_mul/mm 1024 >> ./matrix_mul/mm.csv ; ./matrix_mul/mm 2048 >> ./matrix_mul/mm.csv"

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
# Out:
# <style type="text/css">
# #T_a39ca_row0_col0, #T_a39ca_row0_col1, #T_a39ca_row0_col2, #T_a39ca_row0_col3, #T_a39ca_row0_col4, #T_a39ca_row0_col5, #T_a39ca_row0_col6, #T_a39ca_row0_col7, #T_a39ca_row1_col0, #T_a39ca_row1_col1, #T_a39ca_row1_col2, #T_a39ca_row1_col3, #T_a39ca_row1_col4, #T_a39ca_row1_col5, #T_a39ca_row1_col6, #T_a39ca_row1_col7, #T_a39ca_row2_col0, #T_a39ca_row2_col1, #T_a39ca_row2_col2, #T_a39ca_row2_col3, #T_a39ca_row2_col4, #T_a39ca_row2_col5, #T_a39ca_row2_col6, #T_a39ca_row2_col7 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_a39ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a39ca_level0_col0" class="col_heading level0 col0" >IC</th>
#       <th id="T_a39ca_level0_col1" class="col_heading level0 col1" >Cycles</th>
#       <th id="T_a39ca_level0_col2" class="col_heading level0 col2" >CPI</th>
#       <th id="T_a39ca_level0_col3" class="col_heading level0 col3" >CT_ns</th>
#       <th id="T_a39ca_level0_col4" class="col_heading level0 col4" >ET_s</th>
#       <th id="T_a39ca_level0_col5" class="col_heading level0 col5" >DL1_miss_rate</th>
#       <th id="T_a39ca_level0_col6" class="col_heading level0 col6" >DL1_misses</th>
#       <th id="T_a39ca_level0_col7" class="col_heading level0 col7" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a39ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a39ca_row0_col0" class="data row0 col0" >1077421136</td>
#       <td id="T_a39ca_row0_col1" class="data row0 col1" >740950660</td>
#       <td id="T_a39ca_row0_col2" class="data row0 col2" >0.687708</td>
#       <td id="T_a39ca_row0_col3" class="data row0 col3" >0.213694</td>
#       <td id="T_a39ca_row0_col4" class="data row0 col4" >0.158337</td>
#       <td id="T_a39ca_row0_col5" class="data row0 col5" >0.242821</td>
#       <td id="T_a39ca_row0_col6" class="data row0 col6" >130571299</td>
#       <td id="T_a39ca_row0_col7" class="data row0 col7" >537727247</td>
#     </tr>
#     <tr>
#       <th id="T_a39ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a39ca_row1_col0" class="data row1 col0" >8621075972</td>
#       <td id="T_a39ca_row1_col1" class="data row1 col1" >11060150164</td>
#       <td id="T_a39ca_row1_col2" class="data row1 col2" >1.282920</td>
#       <td id="T_a39ca_row1_col3" class="data row1 col3" >0.192954</td>
#       <td id="T_a39ca_row1_col4" class="data row1 col4" >2.134102</td>
#       <td id="T_a39ca_row1_col5" class="data row1 col5" >0.235004</td>
#       <td id="T_a39ca_row1_col6" class="data row1 col6" >1011566024</td>
#       <td id="T_a39ca_row1_col7" class="data row1 col7" >4304457286</td>
#     </tr>
#     <tr>
#       <th id="T_a39ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a39ca_row2_col0" class="data row2 col0" >68999463366</td>
#       <td id="T_a39ca_row2_col1" class="data row2 col1" >117406516775</td>
#       <td id="T_a39ca_row2_col2" class="data row2 col2" >1.701557</td>
#       <td id="T_a39ca_row2_col3" class="data row2 col3" >0.192907</td>
#       <td id="T_a39ca_row2_col4" class="data row2 col4" >22.648542</td>
#       <td id="T_a39ca_row2_col5" class="data row2 col5" >0.312074</td>
#       <td id="T_a39ca_row2_col6" class="data row2 col6" >10752614433</td>
#       <td id="T_a39ca_row2_col7" class="data row2 col7" >34455299547</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# WOW! Compuational complexty breaks again! The GEMM performance go wild because of cache misses!

# %% [markdown]
# What kind of misses are we seeing?

# %%
! make -C matrix_mul mm_dump; ./matrix_mul/mm_dump 256 >& mm_dump_address.csv
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/matrix_mul'
# gcc -DHAVE_LINUX_PERF_EVENT_H -DDUMP -O3 mm.c perfstats.c -o mm_dump
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/matrix_mul'

# %%
! echo "element,address" > mm_dump_addresses_digest.csv 
! head -n 101 mm_dump_address.csv | grep "b\[" >> mm_dump_addresses_digest.csv
df = pd.read_csv("mm_dump_addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 49152
B = 64
A = 12
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits)%S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# <style type="text/css">
# #T_0d133_row0_col0, #T_0d133_row0_col1, #T_0d133_row0_col2, #T_0d133_row0_col3, #T_0d133_row1_col0, #T_0d133_row1_col1, #T_0d133_row1_col2, #T_0d133_row1_col3, #T_0d133_row2_col0, #T_0d133_row2_col1, #T_0d133_row2_col2, #T_0d133_row2_col3, #T_0d133_row3_col0, #T_0d133_row3_col1, #T_0d133_row3_col2, #T_0d133_row3_col3, #T_0d133_row4_col0, #T_0d133_row4_col1, #T_0d133_row4_col2, #T_0d133_row4_col3, #T_0d133_row5_col0, #T_0d133_row5_col1, #T_0d133_row5_col2, #T_0d133_row5_col3, #T_0d133_row6_col0, #T_0d133_row6_col1, #T_0d133_row6_col2, #T_0d133_row6_col3, #T_0d133_row7_col0, #T_0d133_row7_col1, #T_0d133_row7_col2, #T_0d133_row7_col3, #T_0d133_row8_col0, #T_0d133_row8_col1, #T_0d133_row8_col2, #T_0d133_row8_col3, #T_0d133_row9_col0, #T_0d133_row9_col1, #T_0d133_row9_col2, #T_0d133_row9_col3, #T_0d133_row10_col0, #T_0d133_row10_col1, #T_0d133_row10_col2, #T_0d133_row10_col3, #T_0d133_row11_col0, #T_0d133_row11_col1, #T_0d133_row11_col2, #T_0d133_row11_col3, #T_0d133_row12_col0, #T_0d133_row12_col1, #T_0d133_row12_col2, #T_0d133_row12_col3, #T_0d133_row13_col0, #T_0d133_row13_col1, #T_0d133_row13_col2, #T_0d133_row13_col3, #T_0d133_row14_col0, #T_0d133_row14_col1, #T_0d133_row14_col2, #T_0d133_row14_col3, #T_0d133_row15_col0, #T_0d133_row15_col1, #T_0d133_row15_col2, #T_0d133_row15_col3, #T_0d133_row16_col0, #T_0d133_row16_col1, #T_0d133_row16_col2, #T_0d133_row16_col3, #T_0d133_row17_col0, #T_0d133_row17_col1, #T_0d133_row17_col2, #T_0d133_row17_col3, #T_0d133_row18_col0, #T_0d133_row18_col1, #T_0d133_row18_col2, #T_0d133_row18_col3, #T_0d133_row19_col0, #T_0d133_row19_col1, #T_0d133_row19_col2, #T_0d133_row19_col3, #T_0d133_row20_col0, #T_0d133_row20_col1, #T_0d133_row20_col2, #T_0d133_row20_col3, #T_0d133_row21_col0, #T_0d133_row21_col1, #T_0d133_row21_col2, #T_0d133_row21_col3, #T_0d133_row22_col0, #T_0d133_row22_col1, #T_0d133_row22_col2, #T_0d133_row22_col3, #T_0d133_row23_col0, #T_0d133_row23_col1, #T_0d133_row23_col2, #T_0d133_row23_col3, #T_0d133_row24_col0, #T_0d133_row24_col1, #T_0d133_row24_col2, #T_0d133_row24_col3, #T_0d133_row25_col0, #T_0d133_row25_col1, #T_0d133_row25_col2, #T_0d133_row25_col3, #T_0d133_row26_col0, #T_0d133_row26_col1, #T_0d133_row26_col2, #T_0d133_row26_col3, #T_0d133_row27_col0, #T_0d133_row27_col1, #T_0d133_row27_col2, #T_0d133_row27_col3, #T_0d133_row28_col0, #T_0d133_row28_col1, #T_0d133_row28_col2, #T_0d133_row28_col3, #T_0d133_row29_col0, #T_0d133_row29_col1, #T_0d133_row29_col2, #T_0d133_row29_col3, #T_0d133_row30_col0, #T_0d133_row30_col1, #T_0d133_row30_col2, #T_0d133_row30_col3, #T_0d133_row31_col0, #T_0d133_row31_col1, #T_0d133_row31_col2, #T_0d133_row31_col3, #T_0d133_row32_col0, #T_0d133_row32_col1, #T_0d133_row32_col2, #T_0d133_row32_col3 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_0d133">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d133_level0_col0" class="col_heading level0 col0" >element</th>
#       <th id="T_0d133_level0_col1" class="col_heading level0 col1" >address</th>
#       <th id="T_0d133_level0_col2" class="col_heading level0 col2" >tag</th>
#       <th id="T_0d133_level0_col3" class="col_heading level0 col3" >index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d133_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d133_row0_col0" class="data row0 col0" >b[0][0]</td>
#       <td id="T_0d133_row0_col1" class="data row0 col1" >0x7ccb5d0ff000</td>
#       <td id="T_0d133_row0_col2" class="data row0 col2" >0x7ccb5d0ff</td>
#       <td id="T_0d133_row0_col3" class="data row0 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d133_row1_col0" class="data row1 col0" >b[1][0]</td>
#       <td id="T_0d133_row1_col1" class="data row1 col1" >0x7ccb5d0ff800</td>
#       <td id="T_0d133_row1_col2" class="data row1 col2" >0x7ccb5d0ff</td>
#       <td id="T_0d133_row1_col3" class="data row1 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d133_row2_col0" class="data row2 col0" >b[2][0]</td>
#       <td id="T_0d133_row2_col1" class="data row2 col1" >0x7ccb5d100000</td>
#       <td id="T_0d133_row2_col2" class="data row2 col2" >0x7ccb5d100</td>
#       <td id="T_0d133_row2_col3" class="data row2 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d133_row3_col0" class="data row3 col0" >b[3][0]</td>
#       <td id="T_0d133_row3_col1" class="data row3 col1" >0x7ccb5d100800</td>
#       <td id="T_0d133_row3_col2" class="data row3 col2" >0x7ccb5d100</td>
#       <td id="T_0d133_row3_col3" class="data row3 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d133_row4_col0" class="data row4 col0" >b[4][0]</td>
#       <td id="T_0d133_row4_col1" class="data row4 col1" >0x7ccb5d101000</td>
#       <td id="T_0d133_row4_col2" class="data row4 col2" >0x7ccb5d101</td>
#       <td id="T_0d133_row4_col3" class="data row4 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d133_row5_col0" class="data row5 col0" >b[5][0]</td>
#       <td id="T_0d133_row5_col1" class="data row5 col1" >0x7ccb5d101800</td>
#       <td id="T_0d133_row5_col2" class="data row5 col2" >0x7ccb5d101</td>
#       <td id="T_0d133_row5_col3" class="data row5 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d133_row6_col0" class="data row6 col0" >b[6][0]</td>
#       <td id="T_0d133_row6_col1" class="data row6 col1" >0x7ccb5d102000</td>
#       <td id="T_0d133_row6_col2" class="data row6 col2" >0x7ccb5d102</td>
#       <td id="T_0d133_row6_col3" class="data row6 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0d133_row7_col0" class="data row7 col0" >b[7][0]</td>
#       <td id="T_0d133_row7_col1" class="data row7 col1" >0x7ccb5d102800</td>
#       <td id="T_0d133_row7_col2" class="data row7 col2" >0x7ccb5d102</td>
#       <td id="T_0d133_row7_col3" class="data row7 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0d133_row8_col0" class="data row8 col0" >b[8][0]</td>
#       <td id="T_0d133_row8_col1" class="data row8 col1" >0x7ccb5d103000</td>
#       <td id="T_0d133_row8_col2" class="data row8 col2" >0x7ccb5d103</td>
#       <td id="T_0d133_row8_col3" class="data row8 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0d133_row9_col0" class="data row9 col0" >b[9][0]</td>
#       <td id="T_0d133_row9_col1" class="data row9 col1" >0x7ccb5d103800</td>
#       <td id="T_0d133_row9_col2" class="data row9 col2" >0x7ccb5d103</td>
#       <td id="T_0d133_row9_col3" class="data row9 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0d133_row10_col0" class="data row10 col0" >b[10][0]</td>
#       <td id="T_0d133_row10_col1" class="data row10 col1" >0x7ccb5d104000</td>
#       <td id="T_0d133_row10_col2" class="data row10 col2" >0x7ccb5d104</td>
#       <td id="T_0d133_row10_col3" class="data row10 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0d133_row11_col0" class="data row11 col0" >b[11][0]</td>
#       <td id="T_0d133_row11_col1" class="data row11 col1" >0x7ccb5d104800</td>
#       <td id="T_0d133_row11_col2" class="data row11 col2" >0x7ccb5d104</td>
#       <td id="T_0d133_row11_col3" class="data row11 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_0d133_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0d133_row12_col0" class="data row12 col0" >b[12][0

# %% [markdown]
# ### Matrix tiling algorithm
#
# Let's try to partition GEMM into smaller tiles!

# %%
render_code("matrix_mul/blockmm.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm.c:59-77 (19 lines)
# //START
# void blockmm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#               for(kk = k; kk < k+tile_size; kk++)
#                 c[ii][jj] += a[ii][kk]*b[kk][jj];
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul/; make blockmm
# Out:
# gcc -O3 -DHAVE_LINUX_PERF_EVENT_H blockmm.c perfstats.c -o blockmm
# blockmm.c: In function ‘main’:
# blockmm.c:48:16: warning: format ‘%lu’ expects argument of type ‘long unsigned int’, but argument 3 has type ‘int’ [-Wformat=]
#    48 |   printf("%d,%lu,",ARRAY_SIZE,tile_size);
#       |              ~~^              ~~~~~~~~~
#       |                |              |
#       |                |              int
#       |                long unsigned int
#       |              %u

# %%
! cd matrix_mul; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm.csv
! ./matrix_mul/blockmm 512 8 >> ./matrix_mul/blockmm.csv ;./matrix_mul/blockmm 1024 8 >> ./matrix_mul/blockmm.csv ; ./matrix_mul/blockmm 2048 8 >> ./matrix_mul/blockmm.csv; ./matrix_mul/blockmm 4096 8 >> ./matrix_mul/blockmm.csv

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
# Out:
# <style type="text/css">
# #T_3acc2_row0_col0, #T_3acc2_row0_col1, #T_3acc2_row0_col2, #T_3acc2_row0_col3, #T_3acc2_row0_col4, #T_3acc2_row0_col5, #T_3acc2_row0_col6, #T_3acc2_row0_col7, #T_3acc2_row0_col8, #T_3acc2_row1_col0, #T_3acc2_row1_col1, #T_3acc2_row1_col2, #T_3acc2_row1_col3, #T_3acc2_row1_col4, #T_3acc2_row1_col5, #T_3acc2_row1_col6, #T_3acc2_row1_col7, #T_3acc2_row1_col8, #T_3acc2_row2_col0, #T_3acc2_row2_col1, #T_3acc2_row2_col2, #T_3acc2_row2_col3, #T_3acc2_row2_col4, #T_3acc2_row2_col5, #T_3acc2_row2_col6, #T_3acc2_row2_col7, #T_3acc2_row2_col8 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_3acc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3acc2_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_3acc2_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_3acc2_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_3acc2_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_3acc2_level0_col4" class="col_heading level0 col4" >CT_ns</th>
#       <th id="T_3acc2_level0_col5" class="col_heading level0 col5" >ET_s</th>
#       <th id="T_3acc2_level0_col6" class="col_heading level0 col6" >DL1_miss_rate</th>
#       <th id="T_3acc2_level0_col7" class="col_heading level0 col7" >DL1_misses</th>
#       <th id="T_3acc2_level0_col8" class="col_heading level0 col8" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3acc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3acc2_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_3acc2_row0_col1" class="data row0 col1" >1061097291</td>
#       <td id="T_3acc2_row0_col2" class="data row0 col2" >773717636</td>
#       <td id="T_3acc2_row0_col3" class="data row0 col3" >0.729167</td>
#       <td id="T_3acc2_row0_col4" class="data row0 col4" >0.226353</td>
#       <td id="T_3acc2_row0_col5" class="data row0 col5" >0.175133</td>
#       <td id="T_3acc2_row0_col6" class="data row0 col6" >0.238468</td>
#       <td id="T_3acc2_row0_col7" class="data row0 col7" >126278787</td>
#       <td id="T_3acc2_row0_col8" class="data row0 col8" >529541442</td>
#     </tr>
#     <tr>
#       <th id="T_3acc2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3acc2_row1_col0" class="data row1 col0" >1024</td>
#       <td id="T_3acc2_row1_col1" class="data row1 col1" >8619156556</td>
#       <td id="T_3acc2_row1_col2" class="data row1 col2" >10039092055</td>
#       <td id="T_3acc2_row1_col3" class="data row1 col3" >1.164742</td>
#       <td id="T_3acc2_row1_col4" class="data row1 col4" >0.193245</td>
#       <td id="T_3acc2_row1_col5" class="data row1 col5" >1.940008</td>
#       <td id="T_3acc2_row1_col6" class="data row1 col6" >0.232634</td>
#       <td id="T_3acc2_row1_col7" class="data row1 col7" >1001195428</td>
#       <td id="T_3acc2_row1_col8" class="data row1 col8" >4303733009</td>
#     </tr>
#     <tr>
#       <th id="T_3acc2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_
row1_col2" class="data row1 col2" >8</td>
#       <td id="T_56e79_row1_col3" class="data row1 col3" >10129925601</td>
#       <td id="T_56e79_row1_col4" class="data row1 col4" >2199588954</td>
#       <td id="T_56e79_row1_col5" class="data row1 col5" >0.217138</td>
#       <td id="T_56e79_row1_col6" class="data row1 col6" >0.193574</td>
#       <td id="T_56e79_row1_col7" class="data row1 col7" >0.425784</td>
#       <td id="T_56e79_row1_col8" class="data row1 col8" >0.009332</td>
#       <td id="T_56e79_row1_col9" class="data row1 col9" >44499631</td>
#       <td id="T_56e79_row1_col10" class="data row1 col10" >4768646456</td>
#     </tr>
#     <tr>
#       <th id="T_56e79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_56e79_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_56e79_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_56e79_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_56e79_row2_col3" class="data row2 col3" >81046611334</td>
#       <td id="T_56e79_row2_col4" class="data row2 col4" >21430097264</td>
#       <td id="T_56e79_row2_col5" class="data row2 col5" >0.264417</td>
#       <td id="T_56e79_row2_col6" class="data row2 col6" >0.193320</td>
#       <td id="T_56e79_row2_col7" class="data row2 col7" >4.142870</td>
#       <td id="T_56e79_row2_col8" class="data row2 col8" >0.010273</td>
#       <td id="T_56e79_row2_col9" class="data row2 col9" >391948242</td>
#       <td id="T_56e79_row2_col10" class="data row2 col10" >38151812189</td>
#     </tr>
#     <tr>
#       <th id="T_56e79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_56e79_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_56e79_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_56e79_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_56e79_row3_col3" class="data row3 col3" >648451267176</td>
#       <td id="T_56e79_row3_col4" class="data row3 col4" >215434017013</td>
#       <td id="T_56e79_row3_col5" class="data row3 col5" >0.332229</td>
#       <td id="T_56e79_row3_col6" class="data row3 col6" >0.193189</td>
#       <td id="T_56e79_row3_col7" class="data row3 col7" >41.619418</td>
#       <td id="T_56e79_row3_col8" class="data row3 col8" >0.012172</td>
#       <td id="T_56e79_row3_col9" class="data row3 col9" >3715273312</td>
#       <td id="T_56e79_row3_col10" class="data row3 col10" >305242595577</td>
#     </tr>
#     <tr>
#       <th id="T_56e79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_56e79_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_56e79_row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_56e79_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_56e79_row4_col3" class="data row4 col3" >97764764568</td>
#       <td id="T_56e79_row4_col4" class="data row4 col4" >24002313658</td>
#       <td id="T_56e79_row4_col5" class="data row4 col5" >0.245511</td>
#       <td id="T_56e79_row4_col6" class="data row4 col6" >0.193272</td>
#       <td id="T_56e79_row4_col7" class="data row4 col7" >4.638978</td>
#       <td id="T_56e79_row4_col8" class="data row4 col8" >0.014966</td>
#       <td id="T_56e79_row4_col9" class="data row4 col9" >653117873</td>
#       <td id="T_56e79_row4_col10" class="data row4 col10" >43641172286</td>
#     </tr>
#     <tr>
#       <th id="T_56e79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_56e79_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_56e79_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_56e79_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_56e79_row5_col3" class="data row5 col3" >74379556398</td>
#       <td id=

# %%
render_code("matrix_mul/blockmm_transpose.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_transpose.c:61-79 (19 lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#               for(kk = k; kk < k+tile_size; kk++)
#                 c[ii][jj] += a[ii][kk]*b[jj][kk];
#       }
#     }
#   }
# }
# //END

# %% [markdown]
# ### Matrix transpose

# %%
! cd matrix_mul; make blockmm_transpose; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 512 8 >> ./matrix_mul/blockmm_transpose.csv ;./matrix_mul/blockmm_transpose 1024 8 >> ./matrix_mul/blockmm_transpose.csv ; ./matrix_mul/blockmm_transpose 2048 8 >> ./matrix_mul/blockmm_transpose.csv; ./matrix_mul/blockmm_transpose 4096 8 >> ./matrix_mul/blockmm_transpose.csv
# Out:
# make: 'blockmm_transpose' is up to date.

# %%
! ./matrix_mul/blockmm_transpose 2048 16 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 32 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 64 >> ./matrix_mul/blockmm_transpose.csv

# %%
display_df_mono(render_csv("matrix_mul/blockmm_transpose.csv"))
# Out:
# <style type="text/css">
# #T_2c742_row0_col0, #T_2c742_row0_col1, #T_2c742_row0_col2, #T_2c742_row0_col3, #T_2c742_row0_col4, #T_2c742_row0_col5, #T_2c742_row0_col6, #T_2c742_row0_col7, #T_2c742_row0_col8, #T_2c742_row0_col9, #T_2c742_row0_col10, #T_2c742_row1_col0, #T_2c742_row1_col1, #T_2c742_row1_col2, #T_2c742_row1_col3, #T_2c742_row1_col4, #T_2c742_row1_col5, #T_2c742_row1_col6, #T_2c742_row1_col7, #T_2c742_row1_col8, #T_2c742_row1_col9, #T_2c742_row1_col10, #T_2c742_row2_col0, #T_2c742_row2_col1, #T_2c742_row2_col2, #T_2c742_row2_col3, #T_2c742_row2_col4, #T_2c742_row2_col5, #T_2c742_row2_col6, #T_2c742_row2_col7, #T_2c742_row2_col8, #T_2c742_row2_col9, #T_2c742_row2_col10, #T_2c742_row3_col0, #T_2c742_row3_col1, #T_2c742_row3_col2, #T_2c742_row3_col3, #T_2c742_row3_col4, #T_2c742_row3_col5, #T_2c742_row3_col6, #T_2c742_row3_col7, #T_2c742_row3_col8, #T_2c742_row3_col9, #T_2c742_row3_col10, #T_2c742_row4_col0, #T_2c742_row4_col1, #T_2c742_row4_col2, #T_2c742_row4_col3, #T_2c742_row4_col4, #T_2c742_row4_col5, #T_2c742_row4_col6, #T_2c742_row4_col7, #T_2c742_row4_col8, #T_2c742_row4_col9, #T_2c742_row4_col10, #T_2c742_row5_col0, #T_2c742_row5_col1, #T_2c742_row5_col2, #T_2c742_row5_col3, #T_2c742_row5_col4, #T_2c742_row5_col5, #T_2c742_row5_col6, #T_2c742_row5_col7, #T_2c742_row5_col8, #T_2c742_row5_col9, #T_2c742_row5_col10, #T_2c742_row6_col0, #T_2c742_row6_col1, #T_2c742_row6_col2, #T_2c742_row6_col3, #T_2c742_row6_col4, #T_2c742_row6_col5, #T_2c742_row6_col6, #T_2c742_row6_col7, #T_2c742_row6_col8, #T_2c742_row6_col9, #T_2c742_row6_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_2c742">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c742_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_2c742_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_2c742_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_2c742_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_2c742_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T
row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_2c742_row4_col2" class="data row4 col2" >16</td>
#       <td id="T_2c742_row4_col3" class="data row4 col3" >64810073062</td>
#       <td id="T_2c742_row4_col4" class="data row4 col4" >15221864848</td>
#       <td id="T_2c742_row4_col5" class="data row4 col5" >0.234869</td>
#       <td id="T_2c742_row4_col6" class="data row4 col6" >0.193117</td>
#       <td id="T_2c742_row4_col7" class="data row4 col7" >2.939604</td>
#       <td id="T_2c742_row4_col8" class="data row4 col8" >0.024597</td>
#       <td id="T_2c742_row4_col9" class="data row4 col9" >665236375</td>
#       <td id="T_2c742_row4_col10" class="data row4 col10" >27045326530</td>
#     </tr>
#     <tr>
#       <th id="T_2c742_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c742_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_2c742_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_2c742_row5_col2" class="data row5 col2" >32</td>
#       <td id="T_2c742_row5_col3" class="data row5 col3" >62383258379</td>
#       <td id="T_2c742_row5_col4" class="data row5 col4" >14915042199</td>
#       <td id="T_2c742_row5_col5" class="data row5 col5" >0.239087</td>
#       <td id="T_2c742_row5_col6" class="data row5 col6" >0.193462</td>
#       <td id="T_2c742_row5_col7" class="data row5 col7" >2.885493</td>
#       <td id="T_2c742_row5_col8" class="data row5 col8" >0.041058</td>
#       <td id="T_2c742_row5_col9" class="data row5 col9" >1082281914</td>
#       <td id="T_2c742_row5_col10" class="data row5 col10" >26359904976</td>
#     </tr>
#     <tr>
#       <th id="T_2c742_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c742_row6_col0" class="data row6 col0" >6</td>
#       <td id="

# %%
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
# Out:
# <style type="text/css">
# #T_6775e_row0_col0, #T_6775e_row0_col1, #T_6775e_row0_col2, #T_6775e_row0_col3, #T_6775e_row0_col4, #T_6775e_row0_col5, #T_6775e_row0_col6, #T_6775e_row0_col7, #T_6775e_row0_col8, #T_6775e_row0_col9, #T_6775e_row0_col10, #T_6775e_row1_col0, #T_6775e_row1_col1, #T_6775e_row1_col2, #T_6775e_row1_col3, #T_6775e_row1_col4, #T_6775e_row1_col5, #T_6775e_row1_col6, #T_6775e_row1_col7, #T_6775e_row1_col8, #T_6775e_row1_col9, #T_6775e_row1_col10, #T_6775e_row2_col0, #T_6775e_row2_col1, #T_6775e_row2_col2, #T_6775e_row2_col3, #T_6775e_row2_col4, #T_6775e_row2_col5, #T_6775e_row2_col6, #T_6775e_row2_col7, #T_6775e_row2_col8, #T_6775e_row2_col9, #T_6775e_row2_col10, #T_6775e_row3_col0, #T_6775e_row3_col1, #T_6775e_row3_col2, #T_6775e_row3_col3, #T_6775e_row3_col4, #T_6775e_row3_col5, #T_6775e_row3_col6, #T_6775e_row3_col7, #T_6775e_row3_col8, #T_6775e_row3_col9, #T_6775e_row3_col10, #T_6775e_row4_col0, #T_6775e_row4_col1, #T_6775e_row4_col2, #T_6775e_row4_col3, #T_6775e_row4_col4, #T_6775e_row4_col5, #T_6775e_row4_col6, #T_6775e_row4_col7, #T_6775e_row4_col8, #T_6775e_row4_col9, #T_6775e_row4_col10, #T_6775e_row5_col0, #T_6775e_row5_col1, #T_6775e_row5_col2, #T_6775e_row5_col3, #T_6775e_row5_col4, #T_6775e_row5_col5, #T_6775e_row5_col6, #T_6775e_row5_col7, #T_6775e_row5_col8, #T_6775e_row5_col9, #T_6775e_row5_col10, #T_6775e_row6_col0, #T_6775e_row6_col1, #T_6775e_row6_col2, #T_6775e_row6_col3, #T_6775e_row6_col4, #T_6775e_row6_col5, #T_6775e_row6_col6, #T_6775e_row6_col7, #T_6775e_row6_col8, #T_6775e_row6_col9, #T_6775e_row6_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T
_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6775e_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_6775e_row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_6775e_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_6775e_row4_col3" class="data row4 col3" >97765686275</td>
#       <td id="T_6775e_row4_col4" class="data row4 col4" >24149510064</td>
#       <td id="T_6775e_row4_col5" class="data row4 col5" >0.247014</td>
#       <td id="T_6775e_row4_col6" class="data row4 col6" >0.193189</td>
#       <td id="T_6775e_row4_col7" class="data row4 col7" >4.665430</td>
#       <td id="T_6775e_row4_col8" class="data row4 col8" >0.015102</td>
#       <td id="T_6775e_row4_col9" class="data row4 col9" >659053606</td>
#       <td id="T_6775e_row4_col10" class="data row4 col10" >43641501149</td>
#     </tr>
#     <tr>
#       <th id="T_6775e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6775e_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_6775e_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_6775e_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_6775e_row5_col3" class="data row5 col3" >74473114435</td>
#       <td id="T_6775e_row5_col4" class="data row5 col4" >19369857501</td>
#       <td id="T_6775e_row5_col5" class="data row5 col5" >0.260092</td>
#       <td id="T_6775e_row5_col6" class="data row5 col6" >0.193204</td>
#       <td id="T_6775e_row5_col7" class="data row5 col7" >3.742332</td>
#       <td id="T_6775e_row5_col8" class="data row5 col8" >0.071790</td>
#       <td id="T_6775e_row5_col9" class="data row5 col9" >2591990240</td>
#       <td id="T_6775e_row5_col10" class="data row5 col10" >36105122733</td>
#     </tr>
#     <tr>
#       <th id="T_6775e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6775e_row6_col0" class="data row6 col0" >6</td>
#       <td i

# %% [markdown]
# ## Prefetch
#
# x86 provide prefetch instructions. As a programmer, you may insert ```_mm_prefetch``` in x86 programs to perform software prefetch for your code. The gcc compiler also has a flag ```-fprefetch-loop-arrays``` to automatically insert software prefetch instructions.
#
# ### Using prefetch in matrix transpose code
#
# The following example is a highly optimized matrix transpose code. In the example, we try to prefetch the next row.

# %%
render_code("./prefetch/transpose.cpp", lang="c++", show=["//START", "//END"])
# Out:
# // ./prefetch/transpose.cpp:42-63 (22 lines)
#     //START
#     //  Iterate each row.
#     f_vector *y_iter = T;
#     do{
#         //  Iterate each column.
#         f_vector *ptr_x = y_iter + block;
#         f_vector *ptr_y = y_iter + row_size;
#
#         do{
#
# #ifdef ENABLE_PREFETCH
#             _mm_prefetch((char*)(ptr_y + row_size),_MM_HINT_T0);
# #endif
#             swap_block(ptr_x,ptr_y,block);
#
#             ptr_x += block;
#             ptr_y += row_size;
#         }while (ptr_y < stop_T);
#
#         y_iter += iter_size;
#     }while (y_iter < end);
#     //END

# %% [markdown]
# Now, let's take a look of what's happening!

# %%
! cd prefetch; make clean; make
# ! echo "Without prefetch -- the baseline"; ssh htseng@celebi "lscpu | grep Model; cd courses/CS203/demo/memory/prefetch/; ./transpose"
! echo "Without prefetch -- the baseline"
! lscpu | grep Model
! ./prefetch/transpose
! echo "With prefetch"
! ./prefetch/transpose_prefetch
# Out:
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# Without prefetch -- the baseline
# Model name:                           13th Gen Intel(R) Core(TM) i7-13700
# Model:                                183
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.122648 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.114274 seconds

# %% [markdown]
# Let's try a different machine now.

# %%
! ssh htseng@xerneas "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@xerneas  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@xerneas  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# Model name:                           AMD Ryzen 9 5950X 16-Core Processor
# Model:                                33
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.115205 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.107185 seconds

# %%
! ssh htseng@blissey "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@blissey  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@blissey  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# Model name:                           AMD Ryzen 7 5700X 8-Core Processor
# Model:                                33
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.103619 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.096393 seconds

# %%
! ssh htseng@eevee "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@eevee  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@eevee  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# Model:                              85
# Model name:                         Intel(R) Xeon(R) Silver 4108 CPU @ 1.80GHz
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.199896 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.172947 seconds

# %% [markdown]
# -- It doesn't work always!
